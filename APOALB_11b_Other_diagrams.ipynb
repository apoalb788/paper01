# %% [markdown]
# # Standard Reservoir Computer diagram 3

# %%
from PIL import Image, ImageDraw, ImageFont
from matplotlib import font_manager
import numpy    as np
import networkx as nx
import matplotlib.pyplot as plt
import math     as math
import time     as time

#######################################################################
# E N V I R O N M E N T   S E T   U P
#######################################################################
#---------------------------------------------------------------------#
# To compute elapsed time
#---------------------------------------------------------------------#
start_time = time.time()

# %%
im = Image.new('RGB',(1400, 600),'white')
draw = ImageDraw.Draw(im)

# %%
# comment these lines when development is over
#draw.rectangle((0, 0, 1399, 599), fill='white', outline='black')
#display(im)

# %%
im.save('rho_background.png', quality=95)

# %%
# file seed (for filenames)
txt_seed = 'seed167' 
#

# %%
dx,dy = 0,0

# Overlap images

background  = Image.open("rho_background.png")
foreground  = Image.open('climate/' + txt_seed + "_rho_024_000_N400A.png")
foreground2 = Image.open('climate/' + txt_seed + "_rho_024_000_N400B.png")

background.paste(foreground, (0+dx, 0+dy), foreground)
background.paste(foreground2, (900+dx, 50+dy), foreground2)
display(background)
background.save('climate/' + txt_seed + '_rho_024_000_N400AB.png', quality=95)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1400x600>

# %%
dx,dy = 0,0

# Overlap images

background  = Image.open("rho_background.png")
foreground  = Image.open('climate/' + txt_seed + "_rho_024_058_N400A.png")
foreground2 = Image.open('climate/' + txt_seed + "_rho_024_058_N400B.png")

background.paste(foreground, (0+dx, 0+dy), foreground)
background.paste(foreground2, (900+dx, 50+dy), foreground2)
display(background)
background.save('climate/' + txt_seed + '_rho_024_058_N400AB.png', quality=95)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1400x600>

# %%
dx,dy = 0,0

# Overlap images

background  = Image.open("rho_background.png")
foreground  = Image.open('climate/' + txt_seed + "_rho_024_737_N400A.png")
foreground2 = Image.open('climate/' + txt_seed + "_rho_024_737_N400B.png")

background.paste(foreground, (0+dx, 0+dy), foreground)
background.paste(foreground2, (900+dx, 50+dy), foreground2)
display(background)
background.save('climate/' + txt_seed + '_rho_024_737_N400AB.png', quality=95)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1400x600>

# %%
#---------------------------------------------------------------------#---------------------------------------------------------------------#
# Elapsed time
#---------------------------------------------------------------------#
print(f'\nElapsed time {time.time() - start_time:6.2e} s')
# Out:
# Elapsed time 6.90e-01 s
